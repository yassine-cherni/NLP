# %% [markdown]
# <a href="https://colab.research.google.com/github/yassine-cherni/NLP/blob/main/NLP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install librosa

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename ='/power_on_focus_1.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
### POWER ON FOCUS sound
plt.figure(figsize=(14,5))
data, sample_rate= librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050
